# %%
import pandas as pd
import torch
from torch import cuda
import transformers
from torch.utils.data import Dataset, DataLoader
from transformers import DistilBertModel, DistilBertTokenizer
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
df = pd.read_csv('final-1.csv')
df.rename(columns={'Tags': 'category'}, inplace=True)
categories = ['Funding', 'Operations', 'Misc', 'Food', 'Equipment', 'Programming', 'Travel']
encode_dict = {category: i for i, category in enumerate(categories)}
def encode_cat(x):
    return encode_dict.get(x, -1)
df['ENCODED_CAT'] = df['category'].apply(lambda x: encode_cat(x))
print(df.head())
# Out:
#                                    Memo    category  ENCODED_CAT
# 0      TRANSFER TO STATE HIGH HACK CLUB     Funding            0
# 1                NAME-CHEAP.COM* 8SG11P  Operations            1
# 2            TRANSFER FROM HACK CLUB HQ     Funding            0
# 3                        NAME-CHEAP.COM  Operations            1
# 4  HACK CLUB BANK FEE (MISTAKE BY BANK)        Misc            2

# %%
MAX_LEN = 512
TRAIN_BATCH_SIZE = 4
VALID_BATCH_SIZE = 2
EPOCHS = 5
LEARNING_RATE = 1e-05
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-cased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]

# %%
class Triage(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.len = len(dataframe)
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __getitem__(self, index):
        title = str(self.data.Memo[index])
        title = " ".join(title.split())
        inputs = self.tokenizer.encode_plus(
            title,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            pad_to_max_length=True,
            return_token_type_ids=True,
            truncation=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']

        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'targets': torch.tensor(self.data.ENCODED_CAT[index], dtype=torch.long)
        }

    def __len__(self):
        return self.len

# %%
train_size = 0.8
train_dataset=df.sample(frac=train_size,random_state=200)
test_dataset=df.drop(train_dataset.index).reset_index(drop=True)
train_dataset = train_dataset.reset_index(drop=True)

print("FULL Dataset: {}".format(df.shape))
print("TRAIN Dataset: {}".format(train_dataset.shape))
print("TEST Dataset: {}".format(test_dataset.shape))

training_set = Triage(train_dataset, tokenizer, MAX_LEN)
testing_set = Triage(test_dataset, tokenizer, MAX_LEN)

train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

training_loader = DataLoader(training_set, **train_params)
testing_loader = DataLoader(testing_set, **test_params)
# Out:
# FULL Dataset: (1627, 3)
# TRAIN Dataset: (1302, 3)
# TEST Dataset: (325, 3)

# %%
class DistillBERTClass(torch.nn.Module):
    def __init__(self):
        super(DistillBERTClass, self).__init__()
        self.l1 = DistilBertModel.from_pretrained("distilbert-base-uncased")
        self.pre_classifier = torch.nn.Linear(768, 768)
        self.dropout = torch.nn.Dropout(0.3)
        self.classifier = torch.nn.Linear(768, 7)

    def forward(self, input_ids, attention_mask):
        output_1 = self.l1(input_ids=input_ids, attention_mask=attention_mask)
        hidden_state = output_1[0]
        pooler = hidden_state[:, 0]
        pooler = self.pre_classifier(pooler)
        pooler = torch.nn.ReLU()(pooler)
        pooler = self.dropout(pooler)
        output = self.classifier(pooler)
        return output

# %%
model = DistillBERTClass()
model.to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params =  model.parameters(), lr=LEARNING_RATE)
def calculate_accu(big_idx, targets):
    n_correct = (big_idx==targets).sum().item()
    return n_correct
# Out:
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
def train(epoch):
    tr_loss = 0
    n_correct = 0
    nb_tr_steps = 0
    nb_tr_examples = 0
    model.train()
    for _,data in enumerate(training_loader, 0):
        ids = data['ids'].to(device, dtype = torch.long)
        mask = data['mask'].to(device, dtype = torch.long)
        targets = data['targets'].to(device, dtype = torch.long)

        outputs = model(ids, mask)
        loss = loss_function(outputs, targets)
        tr_loss += loss.item()
        big_val, big_idx = torch.max(outputs.data, dim=1)
        n_correct += calculate_accu(big_idx, targets)

        nb_tr_steps += 1
        nb_tr_examples+=targets.size(0)

        if _%TRAIN_BATCH_SIZE==0:
            loss_step = tr_loss/nb_tr_steps
            accu_step = (n_correct*100)/nb_tr_examples
            print(f"Training Loss per 5000 steps: {loss_step}")
            print(f"Training Accuracy per 5000 steps: {accu_step}")

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f'The Total Accuracy for Epoch {epoch}: {(n_correct*100)/nb_tr_examples}')
    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = (n_correct*100)/nb_tr_examples
    print(f"Training Loss Epoch: {epoch_loss}")
    print(f"Training Accuracy Epoch: {epoch_accu}")

    return

# %%
for epoch in range(EPOCHS):
    train(epoch)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2619: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Training Loss per 5000 steps: 1.951589584350586
# Training Accuracy per 5000 steps: 0.0
# Training Loss per 5000 steps: 1.9311297178268432
# Training Accuracy per 5000 steps: 0.0
# Training Loss per 5000 steps: 1.9212447934680514
# Training Accuracy per 5000 steps: 8.333333333333334
# Training Loss per 5000 steps: 1.914559034200815
# Training Accuracy per 5000 steps: 11.538461538461538
# Training Loss per 5000 steps: 1.9137854716357063
# Training Accuracy per 5000 steps: 17.647058823529413
# Training Loss per 5000 steps: 1.9165904692241125
# Training Accuracy per 5000 steps: 17.857142857142858
# Training Loss per 5000 steps: 1.9043079423904419
# Training Accuracy per 5000 steps: 23.0
# Training Loss per 5000 steps: 1.891768952895855
# Training Accuracy per 5000 steps: 27.586206896551722
# Training Loss per 5000 steps: 1.8884988047859885
# Training Accuracy per 5000 steps: 27.272727272727273
# Training Loss per 5000 steps: 1.8620516061782837
# Training Accuracy per 5000 steps: 31.756756756756758
# Training Loss per 5000 steps: 1.8415344837235241
# Training Accuracy per 5000 steps: 32.31707317073171
# Training Loss per 5000 steps: 1.8499708811442057
# Training Accuracy per 5000 steps: 29.444444444444443
# Training Loss per 5000 steps: 1.8400103121387714
# Training Accuracy per 5000 steps: 30.612244897959183
# Training Loss per 5000 steps: 1.8122283872568383
# Training Accuracy per 5000 steps: 31.60377358490566
# Training Loss per 5000 steps: 1.807407481628552
# Training Accuracy per 5000 steps: 32.01754385964912
# Training Loss per 5000 steps: 1.7811884020195632
# Training Accuracy per 5000 steps: 33.19672131147541
# Training Loss per 5000 steps: 1.7607840391305776
# Training Accuracy per 5000 steps: 33.84615384615385
# Training Loss per 5000 steps: 1.7620716164077537
# Training Accuracy per 5000 steps: 34.05797101449275
# Training Loss per 5000 steps: 1.7653481339755124
# Training Accuracy per 5000 steps: 33.21917808219178
# Training Loss per 5000 steps: 1.7620935331691394
# Training Accuracy per 5000 steps: 33.44155844155844
# Training Loss per 5000 steps: 1.7590321464303098
# Training Accuracy per 5000 steps: 33.95061728395062
# Training Loss per 5000 steps: 1.7559268390431124
# Training Accuracy per 5000 steps: 34.705882352941174
# Training Loss per 5000 steps: 1.7451557148708385
# Training Accuracy per 5000 steps: 34.831460674157306
# Training Loss per 5000 steps: 1.7331064272952337
# Training Accuracy per 5000 steps: 35.483870967741936
# Training Loss per 5000 steps: 1.7265502841202254
# Training Accuracy per 5000 steps: 35.824742268041234
# Training Loss per 5000 steps: 1.7022367550594972
# Training Accuracy per 5000 steps: 37.12871287128713
# Training Loss per 5000 steps: 1.7000266018367949
# Training Accuracy per 5000 steps: 36.666666666666664
# Training Loss per 5000 steps: 1.6939730102862787
# Training Accuracy per 5000 steps: 36.92660550458716
# Training Loss per 5000 steps: 1.6748915145882464
# Training Accuracy per 5000 steps: 37.610619469026545
# Training Loss per 5000 steps: 1.6711029634516463
# Training Accuracy per 5000 steps: 37.60683760683761
# Training Loss per 5000 steps: 1.6579768219269997
# Training Accuracy per 5000 steps: 38.22314049586777
# Training Loss per 5000 steps: 1.6485154719352721
# Training Accuracy per 5000 steps: 38.6
# Training Loss per 5000 steps: 1.6364109035610228
# Training Accuracy per 5000 steps: 39.14728682170543
# Training Loss per 5000 steps: 1.6239932013633556
# Training Accuracy per 5000 steps: 40.225563909774436
# Training Loss per 5000 steps: 1.6161510378774935
# Training Accuracy per 5000 steps: 40.51094890510949
# Training Loss per 5000 steps: 1.6204620177018727
# Training Accuracy per 5000 steps: 40.42553191489362
# Training Loss per 5000 steps: 1.6166105911649506
# Training Accuracy per 5000 steps: 40.3448275862069
# Training Loss per 5000 steps: 1.6146578604742985
# Training Accuracy per 5000 steps: 40.43624161073826
# Training Loss per 5000 steps: 1.6181927319445641
# Training Accuracy per 5000 steps: 40.35947712418301
# Training Loss per 5000 steps: 1.6195393975373287
# Training Accuracy per 5000 steps: 40.445859872611464
# Training Loss per 5000 steps: 1.6066456944305705
# Training Accuracy per 5000 steps: 41.30434782608695
# Training Loss per 5000 steps: 1.5974068489941684
# Training Accuracy per 5000 steps: 41.96969696969697
# Training Loss per 5000 steps: 1.5952673600270197
# Training Accuracy per 5000 steps: 42.30769230769231
# Training Loss per 5000 steps: 1.5953367032067625
# Training Accuracy per 5000 steps: 42.48554913294798
# Training Loss per 5000 steps: 1.5881761406774575
# Training Accuracy per 5000 steps: 42.79661016949152
# Training Loss per 5000 steps: 1.5806297511685619
# Training Accuracy per 5000 steps: 43.0939226519337
# Training Loss per 5000 steps: 1.568090172393902
# Training Accuracy per 5000 steps: 43.91891891891892
# Training Loss per 5000 steps: 1.5691160269515225
# Training Accuracy per 5000 steps: 43.91534391534392
# Training Loss per 5000 steps: 1.5542066084906228
# Training Accuracy per 5000 steps: 44.689119170984455
# Training Loss per 5000 steps: 1.5523079367458519
# Training Accuracy per 5000 steps: 44.54314720812183
# Training Loss per 5000 steps: 1.5497464602859459
# Training Accuracy per 5000 steps: 44.65174129353234
# Training Loss per 5000 steps: 1.540942722413598
# Training Accuracy per 5000 steps: 44.8780487804878
# Training Loss per 5000 steps: 1.536091500777377
# Training Accuracy per 5000 steps: 44.97607655502392
# Training Loss per 5000 steps: 1.5340629611776468
# Training Accuracy per 5000 steps: 45.070422535211264
# Training Loss per 5000 steps: 1.5308885860003634
# Training Accuracy per 5000 steps: 45.046082949308754
# Training Loss per 5000 steps: 1.527229658888476
# Training Accuracy per 5000 steps: 45.13574660633484
# Training Loss per 5000 steps: 1.5179098727968003
# Training Accuracy per 5000 steps: 45.333333333333336
# Training Loss per 5000 steps: 1.5063980458605237
# Training Accuracy per 5000 steps: 45.851528384279476
# Training Loss per 5000 steps: 1.500411203490818
# Training Accuracy per 5000 steps: 45.92274678111588
# Training Loss per 5000 steps: 1.491377724373894
# Training Accuracy per 5000 steps: 46.20253164556962
# Training Loss per 5000 steps: 1.4863579265804212
# Training Accuracy per 5000 steps: 46.57676348547718
# Training Loss per 5000 steps: 1.4808850694675835
# Training Accuracy per 5000 steps: 46.83673469387755
# Training Loss per 5000 steps: 1.472183323768248
# Training Accuracy per 5000 steps: 47.18875502008032
# Training Loss per 5000 steps: 1.4653427801113355
# Training Accuracy per 5000 steps: 47.72727272727273
# Training Loss per 5000 steps: 1.468148874633507
# Training Accuracy per 5000 steps: 47.37354085603113
# Training Loss per 5000 steps: 1.4639136747838895
# Training Accuracy per 5000 steps: 47.509578544061306
# Training Loss per 5000 steps: 1.462560036497296
# Training Accuracy per 5000 steps: 47.64150943396226
# Training Loss per 5000 steps: 1.4656762248078243
# Training Accuracy per 5000 steps: 47.4907063197026
# Training Loss per 5000 steps: 1.4645700520211524
# Training Accuracy per 5000 steps: 47.527472527472526
# Training Loss per 5000 steps: 1.4590665999302366
# Training Accuracy per 5000 steps: 47.83393501805054
# Training Loss per 5000 steps: 1.4550434204607248
# Training Accuracy per 5000 steps: 48.04270462633452
# Training Loss per 5000 steps: 1.445850047730563
# Training Accuracy per 5000 steps: 48.59649122807018
# Training Loss per 5000 steps: 1.443919773126556
# Training Accuracy per 5000 steps: 48.70242214532872
# Training Loss per 5000 steps: 1.4385899683721237
# Training Accuracy per 5000 steps: 48.97610921501707
# Training Loss per 5000 steps: 1.4314370454361143
# Training Accuracy per 5000 steps: 49.32659932659933
# Training Loss per 5000 steps: 1.4250339875585614
# Training Accuracy per 5000 steps: 49.584717607973424
# Training Loss per 5000 steps: 1.4232243510543323
# Training Accuracy per 5000 steps: 49.83606557377049
# Training Loss per 5000 steps: 1.4197063426755392
# Training Accuracy per 5000 steps: 49.919093851132686
# Training Loss per 5000 steps: 1.4152859793113062
# Training Accuracy per 5000 steps: 50.07987220447284
# Training Loss per 5000 steps: 1.4097391296448392
# Training Accuracy per 5000 steps: 50.31545741324921
# Training Loss per 5000 steps: 1.4064432550627866
# Training Accuracy per 5000 steps: 50.467289719626166
# Training Loss per 5000 steps: 1.401485089980639
# Training Accuracy per 5000 steps: 50.69230769230769
# The Total Accuracy for Epoch 0: 50.76804915514593
# Training Loss Epoch: 1.3974530519060562
# Training Accuracy Epoch: 50.76804915514593
# Training Loss per 5000 steps: 0.8734122514724731
# Training Accuracy per 5000 steps: 50.0
# Training Loss per 5000 steps: 0.7977458477020264
# Training Accuracy per 5000 steps: 70.0
# Training Loss per 5000 steps: 0.9172030753559537
# Training Accuracy per 5000 steps: 63.888888888888886
# Training Loss per 5000 steps: 0.8975010697658246
# Training Accuracy per 5000 steps: 65.38461538461539
# Training Loss per 5000 steps: 0.9806456320426044
# Training Accuracy per 5000 steps: 63.23529411764706
# Training Loss per 5000 steps: 1.0341343113354273
# Training Accuracy per 5000 steps: 61.904761904761905
# Training Loss per 5000 steps: 0.9981411457061767
# Training Accuracy per 5000 steps: 64.0
# Training Loss per 5000 steps: 1.0013801794627617
# Training Accuracy per 5000 steps: 64.65517241379311
# Training Loss per 5000 steps: 0.989211051753073
# Training Accuracy per 5000 steps: 65.15151515151516
# Training Loss per 5000 steps: 1.021788170208802
# Training Accuracy per 5000 steps: 64.1891891891892
# Training Loss per 5000 steps: 1.057406607197552
# Training Accuracy per 5000 steps: 62.19512195121951
# Training Loss per 5000 steps: 1.054298108153873
# Training Accuracy per 5000 steps: 62.77777777777778
# Training Loss per 5000 steps: 1.0621325361485383
# Training Accuracy per 5000 steps: 62.755102040816325
# Training Loss per 5000 steps: 1.0383028230577145
# Training Accuracy per 5000 steps: 65.09433962264151
# Training Loss per 5000 steps: 1.0273289910533971
# Training Accuracy per 5000 steps: 66.2280701754386
# Training Loss per 5000 steps: 1.0304294199240012
# Training Accuracy per 5000 steps: 66.39344262295081
# Training Loss per 5000 steps: 1.0306379116498507
# Training Accuracy per 5000 steps: 66.15384615384616
# Training Loss per 5000 steps: 1.0304358437441397
# Training Accuracy per 5000 steps: 66.30434782608695
# Training Loss per 5000 steps: 1.0216101689697945
# Training Accuracy per 5000 steps: 66.43835616438356
# Training Loss per 5000 steps: 1.0146320918937781
# Training Accuracy per 5000 steps: 66.88311688311688
# Training Loss per 5000 steps: 1.0199415367326619
# Training Accuracy per 5000 steps: 66.9753086419753
# Training Loss per 5000 steps: 1.0162188109229593
# Training Accuracy per 5000 steps: 67.3529411764706
# Training Loss per 5000 steps: 1.0224915140130546
# Training Accuracy per 5000 steps: 67.13483146067416
# Training Loss per 5000 steps: 1.0211408542048546
# Training Accuracy per 5000 steps: 67.20430107526882
# Training Loss per 5000 steps: 1.0205643281494219
# Training Accuracy per 5000 steps: 67.01030927835052
# Training Loss per 5000 steps: 1.028327752457987
# Training Accuracy per 5000 steps: 67.07920792079207
# Training Loss per 5000 steps: 1.0286753410384768
# Training Accuracy per 5000 steps: 67.38095238095238
# Training Loss per 5000 steps: 1.0302854210411736
# Training Accuracy per 5000 steps: 66.97247706422019
# Training Loss per 5000 steps: 1.0417061777768937
# Training Accuracy per 5000 steps: 66.3716814159292
# Training Loss per 5000 steps: 1.0528110803192496
# Training Accuracy per 5000 steps: 65.5982905982906
# Training Loss per 5000 steps: 1.0552973493564228
# Training Accuracy per 5000 steps: 65.49586776859505
# Training Loss per 5000 steps: 1.0537128155231477
# Training Accuracy per 5000 steps: 65.4
# Training Loss per 5000 steps: 1.0485792462677919
# Training Accuracy per 5000 steps: 65.69767441860465
# Training Loss per 5000 steps: 1.0552949795597477
# Training Accuracy per 5000 steps: 65.0375939849624
# Training Loss per 5000 steps: 1.0543935723113318
# Training Accuracy per 5000 steps: 65.14598540145985
# Training Loss per 5000 steps: 1.0466444984818182
# Training Accuracy per 5000 steps: 65.2482269503546
# Training Loss per 5000 steps: 1.0386702593030601
# Training Accuracy per 5000 steps: 65.51724137931035
# Training Loss per 5000 steps: 1.0403365654833365
# Training Accuracy per 5000 steps: 65.43624161073825
# Training Loss per 5000 steps: 1.0359411576604531
# Training Accuracy per 5000 steps: 65.52287581699346
# Training Loss per 5000 steps: 1.0410748089954351
# Training Accuracy per 5000 steps: 65.28662420382166
# Training Loss per 5000 steps: 1.0340180276713757
# Training Accuracy per 5000 steps: 65.83850931677019
# Training Loss per 5000 steps: 1.0287713608958504
# Training Accuracy per 5000 steps: 66.36363636363636
# Training Loss per 5000 steps: 1.0212415561697188
# Training Accuracy per 5000 steps: 66.5680473372781
# Training Loss per 5000 steps: 1.0240082534923718
# Training Accuracy per 5000 steps: 66.61849710982659
# Training Loss per 5000 steps: 1.0166462532712914
# Training Accuracy per 5000 steps: 66.66666666666667
# Training Loss per 5000 steps: 1.0187528359791191
# Training Accuracy per 5000 steps: 66.57458563535911
# Training Loss per 5000 steps: 1.0140324148777369
# Training Accuracy per 5000 steps: 66.89189189189189
# Training Loss per 5000 steps: 1.0102929208802167
# Training Accuracy per 5000 steps: 67.06349206349206
# Training Loss per 5000 steps: 1.010325847280458
# Training Accuracy per 5000 steps: 66.83937823834196
# Training Loss per 5000 steps: 1.008750771507999
# Training Accuracy per 5000 steps: 66.87817258883248
# Training Loss per 5000 steps: 1.0122900098117429
# Training Accuracy per 5000 steps: 66.66666666666667
# Training Loss per 5000 steps: 1.0056171949316817
# Training Accuracy per 5000 steps: 67.07317073170732
# Training Loss per 5000 steps: 1.0074337834946847
# Training Accuracy per 5000 steps: 66.98564593301435
# Training Loss per 5000 steps: 1.0053160176590574
# Training Accuracy per 5000 steps: 67.01877934272301
# Training Loss per 5000 steps: 1.002831235596661
# Training Accuracy per 5000 steps: 66.93548387096774
# Training Loss per 5000 steps: 1.001180503837663
# Training Accuracy per 5000 steps: 67.08144796380091
# Training Loss per 5000 steps: 0.9961342232757144
# Training Accuracy per 5000 steps: 67.33333333333333
# Training Loss per 5000 steps: 0.9912564993945793
# Training Accuracy per 5000 steps: 67.68558951965065
# Training Loss per 5000 steps: 0.9891157759105699
# Training Accuracy per 5000 steps: 67.70386266094421
# Training Loss per 5000 steps: 0.9875311583657808
# Training Accuracy per 5000 steps: 67.72151898734177
# Training Loss per 5000 steps: 0.9846059279323118
# Training Accuracy per 5000 steps: 67.73858921161826
# Training Loss per 5000 steps: 0.9892556852223922
# Training Accuracy per 5000 steps: 67.55102040816327
# Training Loss per 5000 steps: 0.987745070792585
# Training Accuracy per 5000 steps: 67.570281124498
# Training Loss per 5000 steps: 0.9850071841784617
# Training Accuracy per 5000 steps: 67.78656126482214
# Training Loss per 5000 steps: 0.981000767549652
# Training Accuracy per 5000 steps: 67.8988326848249
# Training Loss per 5000 steps: 0.9699176158827384
# Training Accuracy per 5000 steps: 68.39080459770115
# Training Loss per 5000 steps: 0.9660101497510694
# Training Accuracy per 5000 steps: 68.49056603773585
# Training Loss per 5000 steps: 0.9665784230351891
# Training Accuracy per 5000 steps: 68.40148698884758
# Training Loss per 5000 steps: 0.9638858214293644
# Training Accuracy per 5000 steps: 68.58974358974359
# Training Loss per 5000 steps: 0.9656195558257912
# Training Accuracy per 5000 steps: 68.50180505415162
# Training Loss per 5000 steps: 0.9560715203501576
# Training Accuracy per 5000 steps: 68.95017793594306
# Training Loss per 5000 steps: 0.9578017330483386
# Training Accuracy per 5000 steps: 68.85964912280701
# Training Loss per 5000 steps: 0.9545451711515242
# Training Accuracy per 5000 steps: 68.9446366782007
# Training Loss per 5000 steps: 0.9549854450156664
# Training Accuracy per 5000 steps: 68.9419795221843
# Training Loss per 5000 steps: 0.9514967162500728
# Training Accuracy per 5000 steps: 69.02356902356902
# Training Loss per 5000 steps: 0.9437358405106884
# Training Accuracy per 5000 steps: 69.35215946843854
# Training Loss per 5000 steps: 0.9427722727666136
# Training Accuracy per 5000 steps: 69.34426229508196
# Training Loss per 5000 steps: 0.9466376879454431
# Training Accuracy per 5000 steps: 69.09385113268608
# Training Loss per 5000 steps: 0.9432420383531827
# Training Accuracy per 5000 steps: 69.24920127795527
# Training Loss per 5000 steps: 0.9435480571225615
# Training Accuracy per 5000 steps: 69.16403785488959
# Training Loss per 5000 steps: 0.9391776528035369
# Training Accuracy per 5000 steps: 69.31464174454828
# Training Loss per 5000 steps: 0.9422959333658218
# Training Accuracy per 5000 steps: 69.3076923076923
# The Total Accuracy for Epoch 1: 69.35483870967742
# Training Loss Epoch: 0.9396885716887705
# Training Accuracy Epoch: 69.35483870967742
# Training Loss per 5000 steps: 0.8097546100616455
# Training Accuracy per 5000 steps: 50.0
# Training Loss per 5000 steps: 0.7536787420511246
# Training Accuracy per 5000 steps: 75.0
# Training Loss per 5000 steps: 0.6771364145808749
# Training Accuracy per 5000 steps: 77.77777777777777
# Training Loss per 5000 steps: 0.7565164153392498
# Training Accuracy per 5000 steps: 75.0
# Training Loss per 5000 steps: 0.7350821407402263
# Training Accuracy per 5000 steps: 76.47058823529412
# Training Loss per 5000 steps: 0.7325224656434286
# Training Accuracy per 5000 steps: 77.38095238095238
# Training Loss per 5000 steps: 0.736498709321022
# Training Accuracy per 5000 steps: 78.0
# Training Loss per 5000 steps: 0.6907427922405046
# Training Accuracy per 5000 steps: 79.3103448275862
# Training Loss per 5000 steps: 0.7136484289711172
# Training Accuracy per 5000 steps: 77.27272727272727
# Training Loss per 5000 steps: 0.6935497341123787
# Training Accuracy per 5000 steps: 78.37837837837837
# Training Loss per 5000 steps: 0.7502807098917845
# Training Accuracy per 5000 steps: 75.60975609756098
# Training Loss per 5000 steps: 0.7579431881507238
# Training Accuracy per 5000 steps: 75.55555555555556
# Training Loss per 5000 steps: 0.7814903493438449
# Training Accuracy per 5000 steps: 74.48979591836735
# Training Loss per 5000 steps: 0.7747769859039558
# Training Accuracy per 5000 steps: 74.52830188679245
# Training Loss per 5000 steps: 0.7751037768627468
# Training Accuracy per 5000 steps: 74.56140350877193
# Training Loss per 5000 steps: 0.7682835862773364
# Training Accuracy per 5000 steps: 74.59016393442623
# Training Loss per 5000 steps: 0.7829296004313689
# Training Accuracy per 5000 steps: 74.23076923076923
# Training Loss per 5000 steps: 0.7589844573235166
# Training Accuracy per 5000 steps: 75.3623188405797
# Training Loss per 5000 steps: 0.7856144721377386
# Training Accuracy per 5000 steps: 73.63013698630137
# Training Loss per 5000 steps: 0.7818447881704801
# Training Accuracy per 5000 steps: 73.37662337662337
# Training Loss per 5000 steps: 0.7663765889994892
# Training Accuracy per 5000 steps: 74.07407407407408
# Training Loss per 5000 steps: 0.7444489803384332
# Training Accuracy per 5000 steps: 75.29411764705883
# Training Loss per 5000 steps: 0.7406599600328488
# Training Accuracy per 5000 steps: 75.56179775280899
# Training Loss per 5000 steps: 0.7287421617456662
# Training Accuracy per 5000 steps: 75.80645161290323
# Training Loss per 5000 steps: 0.7195807904312291
# Training Accuracy per 5000 steps: 76.28865979381443
# Training Loss per 5000 steps: 0.7437453323071546
# Training Accuracy per 5000 steps: 75.24752475247524
# Training Loss per 5000 steps: 0.7547023018201192
# Training Accuracy per 5000 steps: 74.76190476190476
# Training Loss per 5000 steps: 0.758946309942718
# Training Accuracy per 5000 steps: 74.31192660550458
# Training Loss per 5000 steps: 0.7490344717768969
# Training Accuracy per 5000 steps: 74.5575221238938
# Training Loss per 5000 steps: 0.7480852594041926
# Training Accuracy per 5000 steps: 74.57264957264957
# Training Loss per 5000 steps: 0.7485502174139516
# Training Accuracy per 5000 steps: 74.58677685950413
# Training Loss per 5000 steps: 0.7488943727314472
# Training Accuracy per 5000 steps: 74.8
# Training Loss per 5000 steps: 0.7430312142873458
# Training Accuracy per 5000 steps: 74.8062015503876
# Training Loss per 5000 steps: 0.7402477487641618
# Training Accuracy per 5000 steps: 75.0
# Training Loss per 5000 steps: 0.7366574149116547
# Training Accuracy per 5000 steps: 75.18248175182482
# Training Loss per 5000 steps: 0.7354501383577255
# Training Accuracy per 5000 steps: 75.53191489361703
# Training Loss per 5000 steps: 0.7387664189883347
# Training Accuracy per 5000 steps: 75.34482758620689
# Training Loss per 5000 steps: 0.7334384125651129
# Training Accuracy per 5000 steps: 75.50335570469798
# Training Loss per 5000 steps: 0.7303267551306026
# Training Accuracy per 5000 steps: 75.49019607843137
# Training Loss per 5000 steps: 0.7233559058824922
# Training Accuracy per 5000 steps: 75.79617834394904
# Training Loss per 5000 steps: 0.7217853519579639
# Training Accuracy per 5000 steps: 76.08695652173913
# Training Loss per 5000 steps: 0.7152795004573735
# Training Accuracy per 5000 steps: 76.21212121212122
# Training Loss per 5000 steps: 0.7176652750408156
# Training Accuracy per 5000 steps: 76.18343195266272
# Training Loss per 5000 steps: 0.7209929438426316
# Training Accuracy per 5000 steps: 76.01156069364161
# Training Loss per 5000 steps: 0.7182209947604244
# Training Accuracy per 5000 steps: 76.12994350282486
# Training Loss per 5000 steps: 0.709691562643532
# Training Accuracy per 5000 steps: 76.51933701657458
# Training Loss per 5000 steps: 0.7154326621946451
# Training Accuracy per 5000 steps: 76.08108108108108
# Training Loss per 5000 steps: 0.7186935319511033
# Training Accuracy per 5000 steps: 75.92592592592592
# Training Loss per 5000 steps: 0.7169921165959514
# Training Accuracy per 5000 steps: 76.03626943005182
# Training Loss per 5000 steps: 0.7182243034659606
# Training Accuracy per 5000 steps: 76.01522842639594
# Training Loss per 5000 steps: 0.7151794017510331
# Training Accuracy per 5000 steps: 76.24378109452736
# Training Loss per 5000 steps: 0.7153472869679696
# Training Accuracy per 5000 steps: 76.09756097560975
# Training Loss per 5000 steps: 0.7103676621815519
# Training Accuracy per 5000 steps: 76.3157894736842
# Training Loss per 5000 steps: 0.7116216086550777
# Training Accuracy per 5000 steps: 76.29107981220658
# Training Loss per 5000 steps: 0.7104479734901734
# Training Accuracy per 5000 steps: 76.49769585253456
# Training Loss per 5000 steps: 0.7004839380301232
# Training Accuracy per 5000 steps: 76.80995475113122
# Training Loss per 5000 steps: 0.7055122259755929
# Training Accuracy per 5000 steps: 76.55555555555556
# Training Loss per 5000 steps: 0.704237315543484
# Training Accuracy per 5000 steps: 76.52838427947599
# Training Loss per 5000 steps: 0.7028789432807286
# Training Accuracy per 5000 steps: 76.50214592274678
# Training Loss per 5000 steps: 0.7019907457573253
# Training Accuracy per 5000 steps: 76.47679324894514
# Training Loss per 5000 steps: 0.7035755128812246
# Training Accuracy per 5000 steps: 76.55601659751038
# Training Loss per 5000 steps: 0.7020301445862468
# Training Accuracy per 5000 steps: 76.63265306122449
# Training Loss per 5000 steps: 0.7021502407649195
# Training Accuracy per 5000 steps: 76.60642570281125
# Training Loss per 5000 steps: 0.6978939718496894
# Training Accuracy per 5000 steps: 76.77865612648222
# Training Loss per 5000 steps: 0.6962041911534994
# Training Accuracy per 5000 steps: 76.84824902723736
# Training Loss per 5000 steps: 0.6959593736092021
# Training Accuracy per 5000 steps: 76.91570881226053
# Training Loss per 5000 steps: 0.6935061856401417
# Training Accuracy per 5000 steps: 76.98113207547169
# Training Loss per 5000 steps: 0.692458053628419
# Training Accuracy per 5000 steps: 76.95167286245353
# Training Loss per 5000 steps: 0.6932541733614472
# Training Accuracy per 5000 steps: 76.92307692307692
# Training Loss per 5000 steps: 0.6896503251113186
# Training Accuracy per 5000 steps: 77.07581227436823
# Training Loss per 5000 steps: 0.689917687392956
# Training Accuracy per 5000 steps: 77.04626334519573
# Training Loss per 5000 steps: 0.6849452109974727
# Training Accuracy per 5000 steps: 77.28070175438596
# Training Loss per 5000 steps: 0.6848736101419868
# Training Accuracy per 5000 steps: 77.33564013840831
# Training Loss per 5000 steps: 0.6891288146274895
# Training Accuracy per 5000 steps: 77.2184300341297
# Training Loss per 5000 steps: 0.6931988025203297
# Training Accuracy per 5000 steps: 77.10437710437711
# Training Loss per 5000 steps: 0.696979766495006
# Training Accuracy per 5000 steps: 77.07641196013289
# Training Loss per 5000 steps: 0.6955169751751619
# Training Accuracy per 5000 steps: 77.1311475409836
# Training Loss per 5000 steps: 0.6941555758461984
# Training Accuracy per 5000 steps: 77.26537216828478
# Training Loss per 5000 steps: 0.6903577700447732
# Training Accuracy per 5000 steps: 77.47603833865814
# Training Loss per 5000 steps: 0.6872190994560154
# Training Accuracy per 5000 steps: 77.52365930599369
# Training Loss per 5000 steps: 0.6878213919351034
# Training Accuracy per 5000 steps: 77.49221183800623
# Training Loss per 5000 steps: 0.6871701312294373
# Training Accuracy per 5000 steps: 77.53846153846153
# The Total Accuracy for Epoch 2: 77.57296466973887
# Training Loss Epoch: 0.6862329573033412
# Training Accuracy Epoch: 77.57296466973887
# Training Loss per 5000 steps: 0.3874049782752991
# Training Accuracy per 5000 steps: 100.0
# Training Loss per 5000 steps: 0.5767740875482559
# Training Accuracy per 5000 steps: 85.0
# Training Loss per 5000 steps: 0.5234566165341271
# Training Accuracy per 5000 steps: 86.11111111111111
# Training Loss per 5000 steps: 0.5021566797334415
# Training Accuracy per 5000 steps: 86.53846153846153
# Training Loss per 5000 steps: 0.49731748047120433
# Training Accuracy per 5000 steps: 86.76470588235294
# Training Loss per 5000 steps: 0.48179731251938
# Training Accuracy per 5000 steps: 86.9047619047619
# Training Loss per 5000 steps: 0.491682463735342
# Training Accuracy per 5000 steps: 87.0
# Training Loss per 5000 steps: 0.4561463039496849
# Training Accuracy per 5000 steps: 87.93103448275862
# Training Loss per 5000 steps: 0.48336309894467844
# Training Accuracy per 5000 steps: 87.12121212121212
# Training Loss per 5000 steps: 0.481012180749629
# Training Accuracy per 5000 steps: 87.16216216216216
# Training Loss per 5000 steps: 0.4796858610721623
# Training Accuracy per 5000 steps: 87.1951219512195
# Training Loss per 5000 steps: 0.4703477959665987
# Training Accuracy per 5000 steps: 87.22222222222223
# Training Loss per 5000 steps: 0.48787221320125523
# Training Accuracy per 5000 steps: 85.71428571428571
# Training Loss per 5000 steps: 0.4994827461833099
# Training Accuracy per 5000 steps: 85.37735849056604
# Training Loss per 5000 steps: 0.4879323406831214
# Training Accuracy per 5000 steps: 85.96491228070175
# Training Loss per 5000 steps: 0.505459797248
# Training Accuracy per 5000 steps: 85.24590163934427
# Training Loss per 5000 steps: 0.5053943879902363
# Training Accuracy per 5000 steps: 85.0
# Training Loss per 5000 steps: 0.5018355990557567
# Training Accuracy per 5000 steps: 85.5072463768116
# Training Loss per 5000 steps: 0.5048790983855724
# Training Accuracy per 5000 steps: 85.61643835616438
# Training Loss per 5000 steps: 0.5092972851322068
# Training Accuracy per 5000 steps: 85.06493506493507
# Training Loss per 5000 steps: 0.5010148722356484
# Training Accuracy per 5000 steps: 85.49382716049382
# Training Loss per 5000 steps: 0.5006759743041852
# Training Accuracy per 5000 steps: 85.88235294117646
# Training Loss per 5000 steps: 0.5069420868007655
# Training Accuracy per 5000 steps: 85.67415730337079
# Training Loss per 5000 steps: 0.5031194269897477
# Training Accuracy per 5000 steps: 86.02150537634408
# Training Loss per 5000 steps: 0.5084925720602581
# Training Accuracy per 5000 steps: 85.56701030927834
# Training Loss per 5000 steps: 0.5147280400563584
# Training Accuracy per 5000 steps: 85.14851485148515
# Training Loss per 5000 steps: 0.5172622837835834
# Training Accuracy per 5000 steps: 85.0
# Training Loss per 5000 steps: 0.5161943409352674
# Training Accuracy per 5000 steps: 85.3211009174312
# Training Loss per 5000 steps: 0.5103128524414734
# Training Accuracy per 5000 steps: 85.39823008849558
# Training Loss per 5000 steps: 0.5069726054421347
# Training Accuracy per 5000 steps: 85.25641025641026
# Training Loss per 5000 steps: 0.5000611188675254
# Training Accuracy per 5000 steps: 85.53719008264463
# Training Loss per 5000 steps: 0.49664099714159965
# Training Accuracy per 5000 steps: 85.8
# Training Loss per 5000 steps: 0.49558117451478345
# Training Accuracy per 5000 steps: 85.85271317829458
# Training Loss per 5000 steps: 0.488015259847157
# Training Accuracy per 5000 steps: 86.09022556390977
# Training Loss per 5000 steps: 0.4827126439687979
# Training Accuracy per 5000 steps: 86.13138686131387
# Training Loss per 5000 steps: 0.4912873212750076
# Training Accuracy per 5000 steps: 85.46099290780141
# Training Loss per 5000 steps: 0.49041802636508286
# Training Accuracy per 5000 steps: 85.6896551724138
# Training Loss per 5000 steps: 0.4971554864998032
# Training Accuracy per 5000 steps: 85.23489932885906
# Training Loss per 5000 steps: 0.49387225806956586
# Training Accuracy per 5000 steps: 85.29411764705883
# Training Loss per 5000 steps: 0.49873947761478316
# Training Accuracy per 5000 steps: 85.03184713375796
# Training Loss per 5000 steps: 0.49579196331895287
# Training Accuracy per 5000 steps: 85.24844720496894
# Training Loss per 5000 steps: 0.49719399052361646
# Training Accuracy per 5000 steps: 85.15151515151516
# Training Loss per 5000 steps: 0.4913377658348288
# Training Accuracy per 5000 steps: 85.35502958579882
# Training Loss per 5000 steps: 0.4895334235699363
# Training Accuracy per 5000 steps: 85.40462427745665
# Training Loss per 5000 steps: 0.48969992579587096
# Training Accuracy per 5000 steps: 85.59322033898304
# Training Loss per 5000 steps: 0.4921137535872545
# Training Accuracy per 5000 steps: 85.6353591160221
# Training Loss per 5000 steps: 0.496922702090563
# Training Accuracy per 5000 steps: 85.54054054054055
# Training Loss per 5000 steps: 0.49461197948684454
# Training Accuracy per 5000 steps: 85.44973544973546
# Training Loss per 5000 steps: 0.486788570099158
# Training Accuracy per 5000 steps: 85.75129533678756
# Training Loss per 5000 steps: 0.48953310463596417
# Training Accuracy per 5000 steps: 85.53299492385787
# Training Loss per 5000 steps: 0.49336548563815763
# Training Accuracy per 5000 steps: 85.32338308457712
# Training Loss per 5000 steps: 0.490097020630066
# Training Accuracy per 5000 steps: 85.36585365853658
# Training Loss per 5000 steps: 0.4910175572439101
# Training Accuracy per 5000 steps: 85.4066985645933
# Training Loss per 5000 steps: 0.48987581492554694
# Training Accuracy per 5000 steps: 85.44600938967136
# Training Loss per 5000 steps: 0.48567361507375945
# Training Accuracy per 5000 steps: 85.59907834101382
# Training Loss per 5000 steps: 0.48319693734844077
# Training Accuracy per 5000 steps: 85.74660633484163
# Training Loss per 5000 steps: 0.48431871224608686
# Training Accuracy per 5000 steps: 85.66666666666667
# Training Loss per 5000 steps: 0.4821680032579009
# Training Accuracy per 5000 steps: 85.69868995633188
# Training Loss per 5000 steps: 0.4793314951444005
# Training Accuracy per 5000 steps: 85.83690987124463
# Training Loss per 5000 steps: 0.47758283888143077
# Training Accuracy per 5000 steps: 85.9704641350211
# Training Loss per 5000 steps: 0.4761639925655117
# Training Accuracy per 5000 steps: 85.99585062240664
# Training Loss per 5000 steps: 0.4760375108873966
# Training Accuracy per 5000 steps: 85.91836734693878
# Training Loss per 5000 steps: 0.47404493468563
# Training Accuracy per 5000 steps: 85.8433734939759
# Training Loss per 5000 steps: 0.47783134779764025
# Training Accuracy per 5000 steps: 85.7707509881423
# Training Loss per 5000 steps: 0.4753333037421977
# Training Accuracy per 5000 steps: 85.7976653696498
# Training Loss per 5000 steps: 0.47522913638174075
# Training Accuracy per 5000 steps: 85.82375478927203
# Training Loss per 5000 steps: 0.47570833984832717
# Training Accuracy per 5000 steps: 85.84905660377359
# Training Loss per 5000 steps: 0.4744081124247893
# Training Accuracy per 5000 steps: 85.96654275092936
# Training Loss per 5000 steps: 0.4799602976403175
# Training Accuracy per 5000 steps: 85.62271062271063
# Training Loss per 5000 steps: 0.47846781408636146
# Training Accuracy per 5000 steps: 85.5595667870036
# Training Loss per 5000 steps: 0.4820653661237068
# Training Accuracy per 5000 steps: 85.40925266903915
# Training Loss per 5000 steps: 0.4782323627879745
# Training Accuracy per 5000 steps: 85.52631578947368
# Training Loss per 5000 steps: 0.47635279791784124
# Training Accuracy per 5000 steps: 85.72664359861592
# Training Loss per 5000 steps: 0.4774910842192458
# Training Accuracy per 5000 steps: 85.66552901023891
# Training Loss per 5000 steps: 0.47743317719410966
# Training Accuracy per 5000 steps: 85.60606060606061
# Training Loss per 5000 steps: 0.47898673757514687
# Training Accuracy per 5000 steps: 85.54817275747509
# Training Loss per 5000 steps: 0.48101195110405076
# Training Accuracy per 5000 steps: 85.32786885245902
# Training Loss per 5000 steps: 0.47780391418384116
# Training Accuracy per 5000 steps: 85.4368932038835
# Training Loss per 5000 steps: 0.4758195918612777
# Training Accuracy per 5000 steps: 85.54313099041534
# Training Loss per 5000 steps: 0.4732665004390835
# Training Accuracy per 5000 steps: 85.64668769716089
# Training Loss per 5000 steps: 0.47566272864971204
# Training Accuracy per 5000 steps: 85.43613707165109
# Training Loss per 5000 steps: 0.47369689390063285
# Training Accuracy per 5000 steps: 85.53846153846153
# The Total Accuracy for Epoch 3: 85.56067588325652
# Training Loss Epoch: 0.47376989713795714
# Training Accuracy Epoch: 85.56067588325652
# Training Loss per 5000 steps: 0.3852483928203583
# Training Accuracy per 5000 steps: 100.0
# Training Loss per 5000 steps: 0.28524386659264567
# Training Accuracy per 5000 steps: 90.0
# Training Loss per 5000 steps: 0.3642984649373425
# Training Accuracy per 5000 steps: 86.11111111111111
# Training Loss per 5000 steps: 0.38266083053671396
# Training Accuracy per 5000 steps: 86.53846153846153
# Training Loss per 5000 steps: 0.4127912738305681
# Training Accuracy per 5000 steps: 86.76470588235294
# Training Loss per 5000 steps: 0.4068865387567452
# Training Accuracy per 5000 steps: 88.0952380952381
# Training Loss per 5000 steps: 0.3929811052978039
# Training Accuracy per 5000 steps: 89.0
# Training Loss per 5000 steps: 0.3682725728842719
# Training Accuracy per 5000 steps: 89.65517241379311
# Training Loss per 5000 steps: 0.35721552101048554
# Training Accuracy per 5000 steps: 90.9090909090909
# Training Loss per 5000 steps: 0.3641263061278575
# Training Accuracy per 5000 steps: 90.54054054054055
# Training Loss per 5000 steps: 0.3540994990162733
# Training Accuracy per 5000 steps: 91.46341463414635
# Training Loss per 5000 steps: 0.34246138748195437
# Training Accuracy per 5000 steps: 91.66666666666667
# Training Loss per 5000 steps: 0.3332781943739677
# Training Accuracy per 5000 steps: 91.83673469387755
# Training Loss per 5000 steps: 0.34271790761992615
# Training Accuracy per 5000 steps: 91.98113207547169
# Training Loss per 5000 steps: 0.32587377687818125
# Training Accuracy per 5000 steps: 92.54385964912281
# Training Loss per 5000 steps: 0.3433791480836321
# Training Accuracy per 5000 steps: 91.80327868852459
# Training Loss per 5000 steps: 0.3345439614298252
# Training Accuracy per 5000 steps: 92.3076923076923
# Training Loss per 5000 steps: 0.3207864418787801
# Training Accuracy per 5000 steps: 92.7536231884058
# Training Loss per 5000 steps: 0.317521109207444
# Training Accuracy per 5000 steps: 92.8082191780822
# Training Loss per 5000 steps: 0.33447885208509187
# Training Accuracy per 5000 steps: 92.20779220779221
# Training Loss per 5000 steps: 0.3387462058690963
# Training Accuracy per 5000 steps: 92.28395061728395
# Training Loss per 5000 steps: 0.3330960648243918
# Training Accuracy per 5000 steps: 92.3529411764706
# Training Loss per 5000 steps: 0.33238872485967835
# Training Accuracy per 5000 steps: 91.85393258426966
# Training Loss per 5000 steps: 0.33212349974420124
# Training Accuracy per 5000 steps: 91.93548387096774
# Training Loss per 5000 steps: 0.3329250826548362
# Training Accuracy per 5000 steps: 91.49484536082474
# Training Loss per 5000 steps: 0.33740520523399997
# Training Accuracy per 5000 steps: 91.58415841584159
# Training Loss per 5000 steps: 0.3472881954518102
# Training Accuracy per 5000 steps: 91.42857142857143
# Training Loss per 5000 steps: 0.3480659582643607
# Training Accuracy per 5000 steps: 91.28440366972477
# Training Loss per 5000 steps: 0.3621554620135411
# Training Accuracy per 5000 steps: 90.929203539823
# Training Loss per 5000 steps: 0.3580823361905467
# Training Accuracy per 5000 steps: 91.02564102564102
# Training Loss per 5000 steps: 0.3479262101194583
# Training Accuracy per 5000 steps: 91.32231404958678
# Training Loss per 5000 steps: 0.3432552950680256
# Training Accuracy per 5000 steps: 91.6
# Training Loss per 5000 steps: 0.34509674503013144
# Training Accuracy per 5000 steps: 91.47286821705427
# Training Loss per 5000 steps: 0.34088064494885895
# Training Accuracy per 5000 steps: 91.54135338345864
# Training Loss per 5000 steps: 0.3351973014047546
# Training Accuracy per 5000 steps: 91.78832116788321
# Training Loss per 5000 steps: 0.331786314804926
# Training Accuracy per 5000 steps: 92.02127659574468
# Training Loss per 5000 steps: 0.32531738430261614
# Training Accuracy per 5000 steps: 92.24137931034483
# Training Loss per 5000 steps: 0.3221686793703761
# Training Accuracy per 5000 steps: 92.28187919463087
# Training Loss per 5000 steps: 0.32814698892773364
# Training Accuracy per 5000 steps: 92.15686274509804
# Training Loss per 5000 steps: 0.3320435273585616
# Training Accuracy per 5000 steps: 92.03821656050955
# Training Loss per 5000 steps: 0.32996226184833677
# Training Accuracy per 5000 steps: 91.92546583850931
# Training Loss per 5000 steps: 0.32915382370014085
# Training Accuracy per 5000 steps: 91.96969696969697
# Training Loss per 5000 steps: 0.3281646341184628
# Training Accuracy per 5000 steps: 91.86390532544378
# Training Loss per 5000 steps: 0.33246283830181195
# Training Accuracy per 5000 steps: 91.61849710982659
# Training Loss per 5000 steps: 0.32896721871874934
# Training Accuracy per 5000 steps: 91.66666666666667
# Training Loss per 5000 steps: 0.32542799012375306
# Training Accuracy per 5000 steps: 91.85082872928177
# Training Loss per 5000 steps: 0.32533385695738565
# Training Accuracy per 5000 steps: 91.89189189189189
# Training Loss per 5000 steps: 0.32570663525688426
# Training Accuracy per 5000 steps: 91.93121693121694
# Training Loss per 5000 steps: 0.3218263899135389
# Training Accuracy per 5000 steps: 91.96891191709845
# Training Loss per 5000 steps: 0.3352322365549691
# Training Accuracy per 5000 steps: 91.49746192893402
# Training Loss per 5000 steps: 0.33692967777247007
# Training Accuracy per 5000 steps: 91.41791044776119
# Training Loss per 5000 steps: 0.3334067008889666
# Training Accuracy per 5000 steps: 91.46341463414635
# Training Loss per 5000 steps: 0.3315690448240301
# Training Accuracy per 5000 steps: 91.50717703349282
# Training Loss per 5000 steps: 0.3302661418049058
# Training Accuracy per 5000 steps: 91.54929577464789
# Training Loss per 5000 steps: 0.33382985861499875
# Training Accuracy per 5000 steps: 91.3594470046083
# Training Loss per 5000 steps: 0.33803550639859825
# Training Accuracy per 5000 steps: 91.289592760181
# Training Loss per 5000 steps: 0.3352981708985236
# Training Accuracy per 5000 steps: 91.44444444444444
# Training Loss per 5000 steps: 0.33419553996124773
# Training Accuracy per 5000 steps: 91.48471615720524
# Training Loss per 5000 steps: 0.3330783483816127
# Training Accuracy per 5000 steps: 91.52360515021459
# Training Loss per 5000 steps: 0.3379755963842514
# Training Accuracy per 5000 steps: 91.24472573839662
# Training Loss per 5000 steps: 0.34438409560062455
# Training Accuracy per 5000 steps: 90.97510373443983
# Training Loss per 5000 steps: 0.34796011354774237
# Training Accuracy per 5000 steps: 90.81632653061224
# Training Loss per 5000 steps: 0.3513659559990687
# Training Accuracy per 5000 steps: 90.66265060240964
# Training Loss per 5000 steps: 0.3495988378875517
# Training Accuracy per 5000 steps: 90.81027667984189
# Training Loss per 5000 steps: 0.35263743394703134
# Training Accuracy per 5000 steps: 90.75875486381322
# Training Loss per 5000 steps: 0.35251373350548904
# Training Accuracy per 5000 steps: 90.7088122605364
# Training Loss per 5000 steps: 0.3519645109034653
# Training Accuracy per 5000 steps: 90.75471698113208
# Training Loss per 5000 steps: 0.35716080928366756
# Training Accuracy per 5000 steps: 90.52044609665427
# Training Loss per 5000 steps: 0.3575921195351106
# Training Accuracy per 5000 steps: 90.56776556776556
# Training Loss per 5000 steps: 0.36148537711210094
# Training Accuracy per 5000 steps: 90.34296028880867
# Training Loss per 5000 steps: 0.36145001059577025
# Training Accuracy per 5000 steps: 90.39145907473309
# Training Loss per 5000 steps: 0.3602881062547104
# Training Accuracy per 5000 steps: 90.43859649122807
# Training Loss per 5000 steps: 0.3571292721154007
# Training Accuracy per 5000 steps: 90.57093425605537
# Training Loss per 5000 steps: 0.3558395466586073
# Training Accuracy per 5000 steps: 90.69965870307168
# Training Loss per 5000 steps: 0.35311497212622805
# Training Accuracy per 5000 steps: 90.82491582491582
# Training Loss per 5000 steps: 0.35545673972905373
# Training Accuracy per 5000 steps: 90.78073089700996
# Training Loss per 5000 steps: 0.35551934900281373
# Training Accuracy per 5000 steps: 90.81967213114754
# Training Loss per 5000 steps: 0.35539754255581346
# Training Accuracy per 5000 steps: 90.77669902912622
# Training Loss per 5000 steps: 0.3527356591581489
# Training Accuracy per 5000 steps: 90.814696485623
# Training Loss per 5000 steps: 0.3492833218898636
# Training Accuracy per 5000 steps: 90.93059936908517
# Training Loss per 5000 steps: 0.3498817784595666
# Training Accuracy per 5000 steps: 90.96573208722741
# Training Loss per 5000 steps: 0.34807189842542774
# Training Accuracy per 5000 steps: 91.07692307692308
# The Total Accuracy for Epoch 4: 91.09062980030723
# Training Loss Epoch: 0.3470637005628115
# Training Accuracy Epoch: 91.09062980030723

# %%
def valid(model, testing_loader, tokenizer, categories):
    model.eval()
    n_correct = 0
    total_loss = 0
    nb_tr_steps = 0
    nb_tr_examples = 0

    with torch.no_grad():
        for _, data in enumerate(testing_loader, 0):
            ids = data['ids'].to(device, dtype=torch.long)
            mask = data['mask'].to(device, dtype=torch.long)
            targets = data['targets'].to(device, dtype=torch.long)

            outputs = model(ids, mask)
            loss = loss_function(outputs, targets)
            total_loss += loss.item()
            big_val, big_idx = torch.max(outputs, dim=1)

            n_correct += (big_idx == targets).sum().item()
            nb_tr_steps += 1
            nb_tr_examples += targets.size(0)

            decoded_inputs = tokenizer.decode(ids[0], skip_special_tokens=True)
            predicted_class = categories[big_idx[0].item()]
            true_class = categories[targets[0].item()]

            print(f"\nInput Text: {decoded_inputs}")
            print(f"Predicted Class: {predicted_class}, True Class: {true_class}")

    avg_loss = total_loss / nb_tr_steps
    accuracy = (n_correct * 100) / nb_tr_examples
    print(f"\nValidation Loss: {avg_loss}")
    print(f"Validation Accuracy: {accuracy}%")

    return accuracy

# %%
categories = ['Funding', 'Operations', 'Misc', 'Food', 'Equipment', 'Programming', 'Travel']
acc = valid(model, testing_loader, tokenizer, categories)
print("Accuracy on test data = %0.2f%%" % acc)
# Out:
# Input Text: AMAZON. COM * 7O9S89HT3 AMZN
# Predicted Class: Misc, True Class: Misc
#
# Input Text: Care Package
# Predicted Class: Misc, True Class: Misc
#
# Input Text: FISCAL SPONSORSHIP
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Hackathon grant from Hack Club
# Predicted Class: Funding, True Class: Funding
#
# Input Text: TRANSFER FROM ACCOUNT TO CARD BALANCE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Porkbun : venturedglobal. org
# Predicted Class: Operations, True Class: Operations
#
# Input Text: Reimbursement : Caleb's Late Night Feast
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Porkbun : nabadminton. org
# Predicted Class: Operations, True Class: Operations
#
# Input Text: INVOICE TO HUDSON RIVER TRADING LLC
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Disbursement to zero out SoM Sticker Shipments
# Predicted Class: Misc, True Class: Misc
#
# Input Text: STAPLES 0200
# Predicted Class: Equipment, True Class: Misc
#
# Input Text: Porkbun : hackforhomeless. club
# Predicted Class: Operations, True Class: Operations
#
# Input Text: AMAZON. COM * UA4WF09G3 AMZN
# Predicted Class: Misc, True Class: Misc
#
# Input Text: FISCAL SPONSORSHIP
# Predicted Class: Funding, True Class: Funding
#
# Input Text: RAZ * SHIPROCKET
# Predicted Class: Misc, True Class: Misc
#
# Input Text: Domestic Travel Stipend for Ayush Nayak
# Predicted Class: Travel, True Class: Travel
#
# Input Text: DONATION FROM REESE ARMSTRONG
# Predicted Class: Funding, True Class: Funding
#
# Input Text: HACKPENN - AGILEBITS REPAYMENT
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Hackathon grant from Hack Club
# Predicted Class: Funding, True Class: Funding
#
# Input Text: The Everyday Cafe
# Predicted Class: Food, True Class: Food
#
# Input Text: GOODWILL OF SAN FRANCI
# Predicted Class: Misc, True Class: Operations
#
# Input Text: PORKBUN. COM
# Predicted Class: Operations, True Class: Operations
#
# Input Text: Bulk Book Order : 20 copies of " Reclaiming Two Spirits " from FABULOSA BOOKS
# Predicted Class: Funding, True Class: Programming
#
# Input Text: CHECKING EXPENSIFY REPORT 39128350 THE HACK FOUNDATION
# Predicted Class: Operations, True Class: Operations
#
# Input Text: STAMPS. COM
# Predicted Class: Programming, True Class: Programming
#
# Input Text: DONATION FROM KITTEN CALFEE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Hackathon grant from Hack Club
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Reimbursement to Pranav for Chipotle catering driver tip
# Predicted Class: Funding, True Class: Food
#
# Input Text: to Rebecca for Zephyr
# Predicted Class: Misc, True Class: Misc
#
# Input Text: → Transfer to Hack Club Reserve : 10 % of Tom and Theresa Preston - Werner Donation
# Predicted Class: Funding, True Class: Funding
#
# Input Text: INVOICE TO SPARKS ACADEMY
# Predicted Class: Funding, True Class: Funding
#
# Input Text: → Transfer to Hack Club Reserve : 10 % of Jacob Colborn Donation
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Overall | 1x Visa Gift Card
# Predicted Class: Misc, True Class: Misc
#
# Input Text: AMAZON. COM * MC3QP46U3 AMZN
# Predicted Class: Misc, True Class: Misc
#
# Input Text: Hackathon grant from Hack Club
# Predicted Class: Funding, True Class: Funding
#
# Input Text: AMAZON TIPS * FT3H19CE3
# Predicted Class: Misc, True Class: Misc
#
# Input Text: AMZN MKTP US * 2G0279P80
# Predicted Class: Misc, True Class: Misc
#
# Input Text: PRASANTH PALLAMR EXPENSIFY R00CSCOGDWST THE HACK FOUNDATION
# Predicted Class: Operations, True Class: Operations
#
# Input Text: AMZN MKTP US * TK7VA6OT1
# Predicted Class: Misc, True Class: Misc
#
# Input Text: International Shipping Reimbursement to Annlee
# Predicted Class: Funding, True Class: Funding
#
# Input Text: DONATION FROM KITTEN CALFEE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: NAME - CHEAP. COM * Z5APRV
# Predicted Class: Operations, True Class: Operations
#
# Input Text: PORKBUN. COM
# Predicted Class: Operations, True Class: Operations
#
# Input Text: Arduino Store : Student Hardware Grant Purchase
# Predicted Class: Equipment, True Class: Funding
#
# Input Text: 99 RANCH MARKET # 12
# Predicted Class: Food, True Class: Food
#
# Input Text: International phone service plan
# Predicted Class: Misc, True Class: Misc
#
# Input Text: TRANSFER TO STATE HIGH HACK CLUB
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Transfer to Montgomery County Public Schools Account
# Predicted Class: Funding, True Class: Funding
#
# Input Text: STAPLES 1766, CARD : LACHLAN CAMPBELL, MEMBER : LACHLAN CAMPBELL
# Predicted Class: Food, True Class: Equipment
#
# Input Text: STREAMYARD. COM
# Predicted Class: Programming, True Class: Programming
#
# Input Text: Hackathon grant from Hack Club
# Predicted Class: Funding, True Class: Funding
#
# Input Text: AMZN MKTP US * TR7BJ0D90
# Predicted Class: Misc, True Class: Programming
#
# Input Text: TRANSFER TO HACK CLUB HQ
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Hack Club Bank fee
# Predicted Class: Misc, True Class: Funding
#
# Input Text: International phone service plan
# Predicted Class: Misc, True Class: Misc
#
# Input Text: RAZ * AIRASIA INDIA LIMIT
# Predicted Class: Operations, True Class: Misc
#
# Input Text: DONATION FROM ELIZABETH QIU
# Predicted Class: Funding, True Class: Funding
#
# Input Text: LINODE. AKAMAI
# Predicted Class: Misc, True Class: Misc
#
# Input Text: WEGMANS # 098, CARD : THEO BLEIER, MEMBER : THEO BLEIER
# Predicted Class: Food, True Class: Food
#
# Input Text: Transfer of remaining Zephyr funds to HQ
# Predicted Class: Funding, True Class: Funding
#
# Input Text: FISCAL SPONSORSHIP
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Porkbun : yfcalliance. com
# Predicted Class: Operations, True Class: Operations
#
# Input Text: FISCAL SPONSORSHIP
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Transfer to Hack Club Reserve : 10 % of Musk Foundation donation
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Payment to POE PCBA Factory for Orpheus Leap Shipment
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Buying item for club in Colombia
# Predicted Class: Misc, True Class: Equipment
#
# Input Text: STAMPS. COM
# Predicted Class: Programming, True Class: Misc
#
# Input Text: FX 173431824000001 INR 65722. 03 RATE : 78. 6864SALARY PAYMENT TO BENEFICIARY
# Predicted Class: Funding, True Class: Funding
#
# Input Text: International phone service plan
# Predicted Class: Misc, True Class: Misc
#
# Input Text: MCDONALD'S F11729
# Predicted Class: Food, True Class: Food
#
# Input Text: Correction to payment made to Kathryn Noll
# Predicted Class: Misc, True Class: Funding
#
# Input Text: → Transfer to Hack Club Reserve : 10 % of 2 / 11 - 2 / 28 / 23 Donations
# Predicted Class: Funding, True Class: Funding
#
# Input Text: GOOGLE DOMAINS
# Predicted Class: Operations, True Class: Operations
#
# Input Text: PIZZA HUT, CARD : MATTHEW STANCIU, MEMBER : MATTHEW STANCIU
# Predicted Class: Food, True Class: Food
#
# Input Text: DIGITALOCEAN. COM
# Predicted Class: Operations, True Class: Operations
#
# Input Text: AMZN MKTP US * X46SF9P43
# Predicted Class: Misc, True Class: Misc
#
# Input Text: → Transfer to Hack Club Reserve : 10 % of September 2023 Donations
# Predicted Class: Funding, True Class: Funding
#
# Input Text: International Travel Stipend
# Predicted Class: Travel, True Class: Travel
#
# Input Text: Amazon order for parts
# Predicted Class: Programming, True Class: Equipment
#
# Input Text: International phone service plan
# Predicted Class: Misc, True Class: Misc
#
# Input Text: Amazon. com : Design Awards Gift Card
# Predicted Class: Misc, True Class: Misc
#
# Input Text: International Travel Stipend
# Predicted Class: Travel, True Class: Travel
#
# Input Text: Hackathon grant from Hack Club
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Expensify Reimbursement to Max Wofford for postal stamps
# Predicted Class: Operations, True Class: Operations
#
# Input Text: VERCEL PRO
# Predicted Class: Programming, True Class: Operations
#
# Input Text: GEORGES MILLS IRVING
# Predicted Class: Misc, True Class: Travel
#
# Input Text: The Diamond Age
# Predicted Class: Misc, True Class: Misc
#
# Input Text: , Snacks, and Cleaning Supplies
# Predicted Class: Food, True Class: Food
#
# Input Text: BESTBUYCOM 0994, CARD : THEO BLEIER, MEMBER : THEO BLEIER
# Predicted Class: Food, True Class: Equipment
#
# Input Text: FISCAL SPONSORSHIP ( NEW )
# Predicted Class: Funding, True Class: Funding
#
# Input Text: INVOICE TO CODE2CONNECT
# Predicted Class: Funding, True Class: Funding
#
# Input Text: MELODY STARLING EXPENSIFY REPORT 40887949 HACK FOUNDATION
# Predicted Class: Operations, True Class: Operations
#
# Input Text: FISCAL SPONSORSHIP
# Predicted Class: Funding, True Class: Funding
#
# Input Text: SAMS CLUB # 6533, CARD : LACHLAN CAMPBELL, MEMBER : LACHLAN CAMPBELL
# Predicted Class: Misc, True Class: Misc
#
# Input Text: PAKWAN RESTAURANT
# Predicted Class: Food, True Class: Food
#
# Input Text: TRANSFER TO COMMUNITY TEAM
# Predicted Class: Funding, True Class: Funding
#
# Input Text: TRANSFER FROM HCB CLEARINGHOUSE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Pirate Ship Shipping label
# Predicted Class: Misc, True Class: Misc
#
# Input Text: DONATION FROM KITTEN CALFEE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: McMaster - Carr : hex nuts
# Predicted Class: Misc, True Class: Misc
#
# Input Text: SQ * TPUMPS FREMONT
# Predicted Class: Food, True Class: Food
#
# Input Text: → Transfer to Hack Club Reserve : 10 % of Paul Miller Donation
# Predicted Class: Funding, True Class: Funding
#
# Input Text: ZOOM. US 888 - 799 - 9666
# Predicted Class: Operations, True Class: Operations
#
# Input Text: Linode Hosting Fees ( Assemble Ticketing )
# Predicted Class: Operations, True Class: Funding
#
# Input Text: Expensify reimbursement to Max Wofford for payroll advance
# Predicted Class: Operations, True Class: Operations
#
# Input Text: INVOICE TO THE FOUNDATION FOR HISPANIC EDUCATION
# Predicted Class: Funding, True Class: Funding
#
# Input Text: UBER * EATS PENDING
# Predicted Class: Food, True Class: Food
#
# Input Text: Masks, Trash Bags, Hand Sanitizer, Keychain Rings
# Predicted Class: Funding, True Class: Equipment
#
# Input Text: FISCAL SPONSORSHIP
# Predicted Class: Funding, True Class: Funding
#
# Input Text: The Diamond Age
# Predicted Class: Misc, True Class: Misc
#
# Input Text: Domestic Travel Stipend for David Song
# Predicted Class: Travel, True Class: Travel
#
# Input Text: AMZN MKTP US * 4W6QG7BO3
# Predicted Class: Misc, True Class: Misc
#
# Input Text: AMZN MKTP US * BM3IF8BQ3
# Predicted Class: Misc, True Class: Misc
#
# Input Text: Stickers!
# Predicted Class: Travel, True Class: Misc
#
# Input Text: Payment to Nora Frank for working hours
# Predicted Class: Funding, True Class: Funding
#
# Input Text: March funding for APAC Community Discretionary Fund
# Predicted Class: Programming, True Class: Programming
#
# Input Text: DT * DULUTH TRADING CO
# Predicted Class: Misc, True Class: Misc
#
# Input Text: MCMASTER - CARR
# Predicted Class: Misc, True Class: Misc
#
# Input Text: SONG WU EXPENSIFY
# Predicted Class: Operations, True Class: Operations
#
# Input Text: MAHACKS V : STAPLES 0063
# Predicted Class: Travel, True Class: Equipment
#
# Input Text: Amazon. com : Design Awards Gift Card
# Predicted Class: Misc, True Class: Misc
#
# Input Text: DONATION FROM REESE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: WIRE OUT 210920321700 202109203217 ; BNF SHAHEEN IQBAL ; OBI GRANT TO BENEFICIARY
# Predicted Class: Funding, True Class: Funding
#
# Input Text: CHECKING EXPENSIFY REPORT 40435250 HACK FOUNDATION
# Predicted Class: Operations, True Class: Operations
#
# Input Text: Hack Club Bank Fee
# Predicted Class: Misc, True Class: Misc
#
# Input Text: DONATION FROM TODD VOYLES
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Mailgun Credit for Ticketing Emails
# Predicted Class: Operations, True Class: Operations
#
# Input Text: RESIDENCE INN NEEDHAM
# Predicted Class: Travel, True Class: Travel
#
# Input Text: FEE REFUND FROM THEO BLEIER INVOICE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: IN N OUT BURGER 193
# Predicted Class: Misc, True Class: Food
#
# Input Text: Renewing mahacks. com
# Predicted Class: Operations, True Class: Operations
#
# Input Text: WWW. BANNERBUZZ. COM
# Predicted Class: Funding, True Class: Programming
#
# Input Text: meeting boba
# Predicted Class: Food, True Class: Misc
#
# Input Text: Digi - Key Electronics : Student Hardware Grant Purchase
# Predicted Class: Travel, True Class: Equipment
#
# Input Text: INVOICE TO CODE NINJAS
# Predicted Class: Funding, True Class: Funding
#
# Input Text: PIRATE SHIP POSTAGE
# Predicted Class: Misc, True Class: Misc
#
# Input Text: DONATION FROM PHOENIX
# Predicted Class: Funding, True Class: Funding
#
# Input Text: AMAZON. COM, CARD : LACHLAN CAMPBELL, MEMBER : LACHLAN CAMPBELL
# Predicted Class: Misc, True Class: Misc
#
# Input Text: TRANSFER TO HCB CLEARINGHOUSE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: DONATION FROM KITTEN CALFEE
# Predicted Class: Funding, True Class: Funding
#
# Input Text: WISE LTD TRNWISE DEVEN JADHAV
# Predicted Class: Misc, True Class: Misc
#
# Input Text: Additional funding for transparent hackathon grants
# Predicted Class: Funding, True Class: Funding
#
# Input Text: DONATION FROM ISHAN GOEL
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Hackathon grant from Hack Club
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Game pieces and NorCal FTC Regionals registration fee
# Predicted Class: Misc, True Class: Misc
#
# Input Text: NAME - CHEAP. COM
# Predicted Class: Operations, True Class: Operations
#
# Input Text: PREMIER PLUS CKG EXPENSIFY
# Predicted Class: Operations, True Class: Operations
#
# Input Text: shipping for Zephyr
# Predicted Class: Misc, True Class: Operations
#
# Input Text: IC * INSTACART * 159
# Predicted Class: Misc, True Class: Misc
#
# Input Text: PSU CREAMERY, CARD : LACHLAN CAMPBELL, MEMBER : LACHLAN CAMPBELL
# Predicted Class: Misc, True Class: Food
#
# Input Text: FISCAL SPONSORSHIP
# Predicted Class: Funding, True Class: Funding
#
# Input Text: BOOKSHOP. ORG
# Predicted Class: Equipment, True Class: Misc
#
# Input Text: T - Shirts from Big Frog
# Predicted Class: Misc, True Class: Equipment
#
# Input Text: UBER * TRIP HELP. UBER. COM
# Predicted Class: Travel, True Class: Travel
#
# Input Text: FISCAL SPONSORSHIP
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Scavenger Hunt Prizes from Adafruit
# Predicted Class: Misc, True Class: Misc
#
# Input Text: DD DOORDASH SHARETEA
# Predicted Class: Food, True Class: Food
#
# Input Text: DONATION FROM AMY LANG TRUST
# Predicted Class: Funding, True Class: Funding
#
# Input Text: → Transfer to Hack Club Reserve : 10 % of Ron Conway Donation
# Predicted Class: Funding, True Class: Funding
#
# Input Text: ( Reimbursed ) Mailgun Fees
# Predicted Class: Travel, True Class: Funding
#
# Input Text: JPL Prize Posters
# Predicted Class: Misc, True Class: Equipment
#
# Input Text: Hackathon grant from Hack Club
# Predicted Class: Funding, True Class: Funding
#
# Input Text: Replacement T - Shirt
# Predicted Class: Equipment, True Class: Misc
#
# Validation Loss: 0.8206640288570861
# Validation Accuracy: 77.84615384615384%
# Accuracy on test data = 77.85%

# %%
# Saving the files for re-use

# output_model_file = '/'
# output_vocab_file = '/'
model_to_save = model
torch.save(model.state_dict(), '/content/best.pkl')
# tokenizer.save_vocabulary(output_vocab_file)

print('Model saved successfully.')
# Out:
# Model saved successfully.
